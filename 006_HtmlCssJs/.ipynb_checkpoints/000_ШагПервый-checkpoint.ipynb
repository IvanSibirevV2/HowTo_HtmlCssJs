# %% [markdown]
# # Задание первое. Не  тратье много времени. Настройка рабочего места.
# Есть и другие варианты. Мы будем пользоваться именно этим.

# %% [markdown]
# - Установить <a href="https://notepad-plus-plus.org/downloads/">Notepad++</a>
# - При установке выбрать русскую локализацию/версию N++.
# - После установки создать из блокнота привет мир файл и открыть его в N++.
# #######################################################################
# ![image.png](attachment:image.png)
# #######################################################################
# ![image-2.png](attachment:image-2.png)
# #######################################################################
# ![image-3.png](attachment:image-3.png)
# #######################################################################
# ![image-4.png](attachment:image-4.png)
# #######################################################################
# ![image-5.png](attachment:image-5.png)

# %%
# %%html
# <!DOCTYPE HTML>
# <html>
#  <head>
#    <meta charset="utf-8">
#   <title>Титульник</title>
#  </head>
#  <body>
#   <p>Привет мир</p>
#   <p>Приве всем</p>
# </body>
# </html>

# %% [markdown]
# - $<!DOCTYPE HTML>$ - необязательный тег начала документа
# - $<html>$ - необязательный тег начала html страници
# - $<head>$ - необязательный тег начала всякого рода заголовков html страници
# - $<meta charset="utf-8">$ - кодировка в браузере
# - $<title>$ - титульник в браузере
# - $<body>$ - необязательный тег тела HTML страниц
# - $</...>$ - закрывающий парный тег
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь нажимаем F5. И указываем путь к нашему файлу. <br/>
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# Получаем открытый в браузере html файл.
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Задание Второе. Настройка рабочего места для чтения и редактирования интерактивных лекций.

# %% [markdown]
# <a href="https://www.anaconda.com/products/individual">Установить менеджер пакетов Pyton Anaconda</a>.<br/>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# Питон вшит в исподнеё, его отдельно устанавливать не обязательно.<br/>
# При установке мы на любые непонятные вопросы соглашаемся и идем дальше.<br/>
# После установки в поиске Windows изем анаконду.<br/>
# ![image-3.png](attachment:image-3.png)
# На ярлыке кликаем правой кнопкой мыши, "Дополнительно/Перейти к расположению файла", копируем путь
# ![image-4.png](attachment:image-4.png)
# На рабочем столе создаем ярлык со скопированным путем...
# ![image-5.png](attachment:image-5.png)
# Открываем Jupiter Noutbook
# ![image-6.png](attachment:image-6.png)
# Если ярлыка нет, То устанавливаем его через анаконду или создаем сами, по аналогии, с вашими путями, это одна строка...
# <code>C:\Users\SibNout2020\anaconda3\python.exe C:\Users\SibNout2020\anaconda3\cwp.py C:\Users\SibNout2020\anaconda3 C:\Users\SibNout2020\anaconda3\python.exe C:\Users\SibNout2020\anaconda3\Scripts\jupyter-notebook-script.py "%USERPROFILE%/"</code>
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
# ![image-9.png](attachment:image-9.png)
# После запуска юпитера, если он не открылся в браузере можно его запустить насильно, по этой строке.

# %% [markdown]
# Что делать если не прокатило.
# <a href="https://jupyter.org/try">jupiter notebook online</a>
# ![image.png](attachment:image.png)
# Очень долго ждем...
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# Очень долго ждем
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)
# Все, в принципе, все открывается, можно работать.<br/>
# При работе с локальным сервером, а не с jupiter notebook online , проблем будет меньше...<br/>
# Все скаченное, на сервер лежит в папке вашего пользователя C:\Users\SibNout2020\...<br/>

# %% [markdown]
# # Задание Третье. Настройка все как у меня =).

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# <a href="https://qastack.ru/programming/33159518/collapse-cell-in-jupyter-notebook">Дальше делаем как на сайте, построчно вбиваем код и нажимаем Enter</a>
# <Code>
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# pip install jupyter_nbextensions_configurator
# jupyter nbextensions_configurator enable --user
# </Code>
# Затем все перезагружаем. Ожидается что на стартовой странице появится вкладка настроек.<br/>
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# Все, теперь все заголовки являются сворачиваемыми.
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# # Задание Четвертое. Не пугаемся и слушаем...

# %% [markdown]
# Сейчас мы услановили достаточно мощьную программистскую читалку, которая позволяет писать текст, программный код и интерактивно, прямо из лекции его запускать.<BR/>
# По себе знаю что N++ В РАЗЫ ЛУЧШЕ ОБЫЧНОГО БЛОКНОТА... Только вот обычная, по нынешним меркам страница, сосоит из $*.html$, $*.js$, $*.css$.<BR/>
# Не набегаемся, чтобы воспроизводить у себя немеренное колличество примеров.<BR/>
# Проще дать в виде интерактивной лекции.<BR/>
# Итак ШифтЕнтер - запуск ячейки.<BR/>
# Ячейки для нас делятся на Markdown - это простой текст с элементами верстки.<BR/>
# И программный Code.
# ![image.png](attachment:image.png)
# Что, бы добавить новую ячейку, нажмите на плюсик (под номером один), захотите удалить ячейку, нажмите ножницы.<BR/>
# Под номером 2 стрелочки в верх и в низ позволяют менять ячейки местами.<br/>
# На кнопки под номером 3 пока вообще не нажимайте.<br/>
# Во вкладке под номером 4 можно поменять тип ячейки.<br/>
# По умолчанию, в ячейке Code - Python, но если вперед написать <code>%%html</code>, то мы получим полноценную вставку на HTML,CSS,JS. Чем для ускорения процесса мы и будем пользоваться в процессе  обучения.
